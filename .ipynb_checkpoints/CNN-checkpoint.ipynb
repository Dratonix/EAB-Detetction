# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # CNN Model 1 (without data augmentation + vae)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255,

                                  validation_split=.25)
train_dir = "NewImages/"

train_data = train_datagen.flow_from_directory(
    train_dir,  # Folder containing your image dataset
    target_size=(224,224),  # Resize images to target size
    batch_size=32,
    class_mode='binary',  # Use None if you're just augmenting data (no labels)
    subset='training',
    shuffle=True
    )
val_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    subset='validation',
    shuffle=True
)

img = next(train_data)
# Out:
# Found 448 images belonging to 2 classes.
# Found 149 images belonging to 2 classes.

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.0].
# array([[[0.5686275 , 0.65882355, 0.7803922 ],
#         [0.7372549 , 0.73333335, 0.6509804 ],
#         [0.81568635, 0.882353  , 0.909804  ],
#         ...,
#         [0.40000004, 0.4784314 , 0.58431375],
#         [0.43137258, 0.5294118 , 0.6156863 ],
#         [0.3372549 , 0.42352945, 0.24313727]],
#
#        [[0.5647059 , 0.6392157 , 0.6666667 ],
#         [0.47450984, 0.46274513, 0.49803925],
#         [0.454902  , 0.5411765 , 0.34901962],
#         ...,
#         [0.4039216 , 0.6431373 , 0.8980393 ],
#         [0.59607846, 0.63529414, 0.67058825],
#         [0.29803923, 0.4901961 , 0.47450984]],
#
#        [[0.5921569 , 0.6745098 , 0.6784314 ],
#         [0.94117653, 0.98823535, 1.        ],
#         [0.9725491 , 1.        , 0.90196085],
#         ...,
#         [0.48235297, 0.75294125, 0.9843138 ],
#         [0.7411765 , 0.76470596, 0.7568628 ],
#         [0.61960787, 0.7411765 , 0.5686275 ]],
#
#        ...,
#
#        [[0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         ...,
#         [1.1568627 , 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943]],
#
#        [[0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         ...,
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943]],
#
#        [[0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         ...,
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943],
#         [0.15686275, 0.18431373, 0.22352943]]], dtype=float32)

# %% [markdown]
# # CNN Model 3 (with data augmetnation + VAE)
