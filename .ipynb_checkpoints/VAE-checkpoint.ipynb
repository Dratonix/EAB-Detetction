# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Preproccess the images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
train_dir = "NewImages/"

train_data = train_datagen.flow_from_directory(
    train_dir,  # Folder containing your image dataset
    target_size=(224,224),  # Resize images to target size
    batch_size=32,
    class_mode=None,  # Use None if you're just augmenting data (no labels)
    shuffle=True
    )

img = next(train_data)
plt.imshow(img[5])
# Out:
# Found 597 images belonging to 2 classes.

# %% [markdown]
# ## Creating noise for data augmentation

# %%
def gaussian_noise(img, mean, stddev, gamma = 1):
    noise=np.zeros(img.shape,np.uint8)
    cv2.randn(noise,mean,stddev)
    noise_img = noise+temp_img
    plt.imshow(noise_img)
    return noise_img

# %%
gaussian_noise(img[0], 0, .3,6)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.9843137].
# array([[[0.04705883, 0.10196079, 0.10588236],
#         [0.04705883, 0.10196079, 0.10588236],
#         [0.0509804 , 0.10588236, 0.10980393],
#         ...,
#         [0.05882353, 0.1137255 , 0.1254902 ],
#         [0.05490196, 0.10980393, 0.1137255 ],
#         [0.05490196, 0.10980393, 0.1137255 ]],
#
#        [[0.04705883, 0.10196079, 0.10588236],
#         [0.0509804 , 0.10588236, 0.10980393],
#         [0.05490196, 0.10980393, 0.1137255 ],
#         ...,
#         [0.05882353, 0.1137255 , 0.1254902 ],
#         [0.05490196, 0.10980393, 0.1137255 ],
#         [0.05490196, 0.10980393, 0.1137255 ]],
#
#        [[0.0509804 , 0.10588236, 0.10980393],
#         [0.0509804 , 0.10588236, 0.10980393],
#         [0.05490196, 0.10980393, 0.1137255 ],
#         ...,
#         [0.05882353, 0.1137255 , 0.1254902 ],
#         [0.05490196, 0.10980393, 0.1137255 ],
#         [0.05490196, 0.10980393, 0.1137255 ]],
#
#        ...,
#
#        [[0.14901961, 0.1764706 , 0.14509805],
#         [0.09803922, 0.14117648, 0.08627451],
#         [0.04705883, 0.09019608, 0.02745098],
#         ...,
#         [0.08627451, 0.14117648, 0.08235294],
#         [0.05882353, 0.1137255 , 0.0627451 ],
#         [0.0509804 , 0.10196079, 0.0627451 ]],
#
#        [[1.1254902 , 0.16470589, 0.12941177],
#         [0.10980393, 0.15294118, 0.09803922],
#         [0.06666667, 0.10980393, 0.04705883],
#         ...,
#         [1.0745099 , 0.12941177, 0.07058824],
#         [0.0509804 , 0.10196079, 0.0627451 ],
#         [0.04313726, 0.09411766, 0.05490196]],
#
#        [[0.05490196, 0.09411766, 0.05882353],
#         [0.06666667, 0.1137255 , 0.05882353],
#         [0.14901961, 0.20000002, 0.13333334],
#         ...,
#         [0.01176471, 0.0627451 , 0.02352941],
#         [0.04705883, 0.09803922, 0.0627451 ],
#         [0.03921569, 0.09019608, 0.05490196]]], dtype=float32)
